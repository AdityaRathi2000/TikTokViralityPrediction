# %%
import numpy
import pandas as pd
from PIL import Image
import requests

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/Shareddrives/CIS 522/code/input/TikTok Data/batch_4_100000/fyp_1650166896697.csv")
len(df)
# Out:
# 975

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       975 non-null    int64
#  1   secretID                 975 non-null    int64
#  2   text                     975 non-null    object
#  3   createTime               975 non-null    int64
#  4   authorMeta.id            975 non-null    int64
#  5   authorMeta.secUid        975 non-null    object
#  6   authorMeta.name          975 non-null    object
#  7   authorMeta.nickName      975 non-null    object
#  8   authorMeta.verified      975 non-null    bool
#  9   authorMeta.signature     936 non-null    object
#  10  authorMeta.avatar        975 non-null    object
#  11  authorMeta.following     975 non-null    int64
#  12  authorMeta.fans          975 non-null    int64
#  13  authorMeta.heart         975 non-null    int64
# ...

# %%
df_cover = df[["id", "covers.default"]]
df_cover
# Out:
#                       id                                     covers.default
# 0    6862153058223197445  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1    6911406868699073798  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2    7028775404173413678  https://p19-sign.tiktokcdn-us.com/obj/tos-usea...
# 3    6975140587196517638  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 4    6984473039605959941  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# ..                   ...                                                ...
# 970  6889900644510059781  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 971  6814512525250530566  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 972  6983419881379155206  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 973  6820442532665707782  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 974  7008907192124312837  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
# [975 rows x 2 columns]

# %%
# IMAGE SAVING
for (_, covers) in df_cover.iterrows():
  id = covers.id
  thumb = covers["covers.default"]
  im = Image.open(requests.get(thumb, stream=True).raw)
  # print(thumb)
  im.save("/content/drive/Shareddrives/CIS 522/code/input/TikTok Data/batch_4_100000/{}.png".format(id))

# %%
df_music = df[["id", "musicMeta.musicId", "musicMeta.musicName"]]
df_music
# Out:
#                      id    musicMeta.musicId musicMeta.musicName
# 0   6862153058223197445  6840839890826038022          M to the B
# 1   6911406868699073798  6854654862202784517            Deep End
# 2   7028775404173413678  7028005731337095942      original sound
# 3   6975140587196517638  6975140417884998405      original sound
# 4   6984473039605959941  6962776558117341953     Trap de Amarela
# ..                  ...                  ...                 ...
# 95  6985227851633020166  6985227747085781766      original sound
# 96  6980140082875419909  6980139905905150726      original sound
# 97  7012988230840732934  7012988140839324422      original sound
# 98  6914708330065743109  6603879522611759878   Inside Their Head
# 99  6959686253600148741  6959686097639197445      original sound
#
# [100 rows x 3 columns]

# %%
import librosa
import librosa.display
#Audio("https://sf16-ies-music-sg.tiktokcdn.com/obj/tos-alisg-ve-2774/015392f39c5947b5ae1e253cba0128f8.mp3")
ar, sr = librosa.load("https://sf16-sg.muscdn.com/obj/tiktok-obj/7fbdd1d4ac0ee21b1c9336fa76d52c78")
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ...
