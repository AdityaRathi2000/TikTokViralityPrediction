# %%
import numpy as np
import pandas as pd
import json
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from google.colab.data_table import DataTable
DataTable.max_columns = 400
import statsmodels.api as sm
import numpy as np
import json
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/Shareddrives/CIS 522/code/input/TikTok Data/batch_4_100000/fyp_1650166896697.csv")
df
# Out:
#                       id             secretID  \
# 0    6862153058223197445  6862153058223197445
# 1    6911406868699073798  6911406868699073798
# 2    7028775404173413678  7028775404173413678
# 3    6975140587196517638  6975140587196517638
# 4    6984473039605959941  6984473039605959941
# ..                   ...                  ...
# 970  6889900644510059781  6889900644510059781
# 971  6814512525250530566  6814512525250530566
# 972  6983419881379155206  6983419881379155206
# 973  6820442532665707782  6820442532665707782
# 974  7008907192124312837  7008907192124312837
#
#                                                   text  createTime  \
# 0                                   To the 🐝 🐝 🐝  #fyp  1597719521
# 1    😳This is one of my best drawings #dlaciebie #t...  1609187323
# 2                  bruh this shit has me WHEEZING #fyp  1636514303
# 3    Fill the cheeks Squishy, fill the cheeks #fyp ...  1624026477
# 4                             #fyp #foryou #foryoupage  1626199356
# ...

# %%
# Df, remove unnecessary
# digg  - LIKES THE PERSON HAS GIVEN
# heart - LIKES THE PERSON HAS GOT
# diggCount - LIKES THE VIDEO RECIEVED
df_1 = df[['id', 'text', 'authorMeta.id',
       'authorMeta.verified',
       'authorMeta.following', 'authorMeta.fans', 'authorMeta.heart',
       'authorMeta.video', 'authorMeta.digg', 'musicMeta.musicId',
       'musicMeta.musicOriginal',
       'musicMeta.duration', 'videoMeta.height', 'videoMeta.width',
       'videoMeta.duration', 'diggCount', 'shareCount', 'playCount',
       'commentCount', 'mentions', 'hashtags', 'effectStickers']]
df_1.head(2)
# Out:
#                     id                                               text  \
# 0  6862153058223197445                                 To the 🐝 🐝 🐝  #fyp
# 1  6911406868699073798  😳This is one of my best drawings #dlaciebie #t...
#
#          authorMeta.id  authorMeta.verified  authorMeta.following  \
# 0  6748458643983238149                 True                   589
# 1  6815820521784787973                 True                    99
#
#    authorMeta.fans  authorMeta.heart  authorMeta.video  authorMeta.digg  \
# 0         89100000        2100000000               458             8327
# 1         11800000         233100000               193            27800
#
#      musicMeta.musicId  ...  videoMeta.height  videoMeta.width  \
# 0  6840839890826038022  ...              1024              576
# 1  6854654862202784517  ...               960              540
#
#    videoMeta.duration  diggCount  shareCount  playCount  commentCount  \
# ...

# %%
# Refining features.
df_1["hashtags_pp"] = df_1["hashtags"].apply(lambda x: [h['name'] for h in json.loads(x)]) #just get name of hashtags
df_1["effectStickers_pp"] = df_1["effectStickers"].apply(lambda x: [es['name'] for es in json.loads(x)]) # just get name of effectStickers
df_1["mentions_pp"] = df_1["mentions"].apply(lambda x: [m for m in json.loads(x)]) # just get name of effectStickers
df_1["caption_pp"] = df_1["text"].apply(lambda x: len(x)) # just get length of caption
df_1["author_verification"] = df_1["authorMeta.verified"].apply(lambda x: 1 if (x == True) else 0) # encode verification
df_1["music_original"] = df_1["musicMeta.musicOriginal"].apply(lambda x: 1 if (x == True) else 0) # encode music meta

df_1["virality_score"] = df_1["musicMeta.musicOriginal"].apply(lambda x: 1 if (x == True) else 0) # encode music meta

df_2 = df_1[['id', 'text', 'caption_pp', 'authorMeta.id', "author_verification",
       'authorMeta.following', 'authorMeta.fans', 'authorMeta.heart',
       'authorMeta.video', 'authorMeta.digg', 'musicMeta.musicId',
       'music_original', 'musicMeta.duration', 'videoMeta.height',
       'videoMeta.width', 'videoMeta.duration', 'diggCount', 'shareCount',
       'playCount', 'commentCount', 'mentions_pp', 'hashtags_pp', 'effectStickers_pp']]


df_2
# Out:
#                       id                                               text  \
# 0    6862153058223197445                                 To the 🐝 🐝 🐝  #fyp
# 1    6911406868699073798  😳This is one of my best drawings #dlaciebie #t...
# 2    7028775404173413678                bruh this shit has me WHEEZING #fyp
# 3    6975140587196517638  Fill the cheeks Squishy, fill the cheeks #fyp ...
# 4    6984473039605959941                           #fyp #foryou #foryoupage
# ..                   ...                                                ...
# 970  6889900644510059781  Christmas lollipop made out of pool noodles. S...
# 971  6814512525250530566  Embracing our cultures #fyp #foryou #foryoupag...
# 972  6983419881379155206                  why do men like this exist ? #fyp
# 973  6820442532665707782     Please don’t be ugly 🐼#fyp #foryou #foryoupage
# 974  7008907192124312837  #fyp #foryou #foryoupage #viral #funny #vegan ...
#
# ...

# %%
### REGRESSION FOR VIRALITY METRIC coefficits
def update_df(df, column, mini_col_name):
  g = [j for sub in list(df[column]) for j in sub]
  no_dups = []
  [no_dups.append(x) for x in g if x not in no_dups]

  for col in no_dups:
    df[mini_col_name+col] = 0

  for i, row in df.iterrows():
    for hashtag in row[column]:
      df.loc[i,mini_col_name+hashtag] += 1

update_df(df_2, "hashtags_pp", "hashtag_")
update_df(df_2, "mentions_pp", "mention_")
update_df(df_2, "effectStickers_pp", "effect_")

# %%
df_3 = df_2.drop(["authorMeta.id", "musicMeta.musicId", "mentions_pp", "hashtags_pp", "effectStickers_pp"], axis=1) 
df_3["views/fans"] = df_3["playCount"] / df_3["authorMeta.fans"]

GET_10_PERC_VIRAL = 40 # Multiple 
df_3["label"] = df_3["views/fans"].apply(lambda x: 1 if (x>GET_10_PERC_VIRAL) else 0)
print("1: {}, 0: {}".format(round(len(df_3[df_3["label"] == 1])/len(df_3) * 100, 2), round(len(df_3[df_3["label"] == 0])/len(df_3) * 100, 2)))
df_4 = df_3.drop(["views/fans"], axis=1) 

df_4
# Out:
# 1: 48.1, 0: 51.9
#                       id                                               text  \
# 0    6862153058223197445                                 To the 🐝 🐝 🐝  #fyp
# 1    6911406868699073798  😳This is one of my best drawings #dlaciebie #t...
# 2    7028775404173413678                bruh this shit has me WHEEZING #fyp
# 3    6975140587196517638  Fill the cheeks Squishy, fill the cheeks #fyp ...
# 4    6984473039605959941                           #fyp #foryou #foryoupage
# ..                   ...                                                ...
# 970  6889900644510059781  Christmas lollipop made out of pool noodles. S...
# 971  6814512525250530566  Embracing our cultures #fyp #foryou #foryoupag...
# 972  6983419881379155206                  why do men like this exist ? #fyp
# 973  6820442532665707782     Please don’t be ugly 🐼#fyp #foryou #foryoupage
# 974  7008907192124312837  #fyp #foryou #foryoupage #viral #funny #vegan ...
#
# ...

# %%
df_4.label.value_counts()
# Out:
# 0    506
# 1    469
# Name: label, dtype: int64

# %%
from pathlib import Path  
filepath = Path('/content/drive/Shareddrives/CIS 522/code/input/TikTok Data/batch_4_100000/data_cleaned_250perc_viral.csv', index=False)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_4.to_csv(filepath)
